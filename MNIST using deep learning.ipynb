# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model .summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              785000
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 795,010
# Trainable params: 795,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time

start_time = time.time()
hist = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                epochs=10, batch_size=100, verbose=1)
print('Fit time :', time.time() - start_time)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 8s 12ms/step - loss: 0.3885 - accuracy: 0.8897 - val_loss: 0.1033 - val_accuracy: 0.9685
# Epoch 2/10
# 600/600 [==============================] - 7s 11ms/step - loss: 0.0871 - accuracy: 0.9746 - val_loss: 0.0780 - val_accuracy: 0.9758
# Epoch 3/10
# 600/600 [==============================] - 6s 11ms/step - loss: 0.0520 - accuracy: 0.9845 - val_loss: 0.0726 - val_accuracy: 0.9769
# Epoch 4/10
# 600/600 [==============================] - 6s 11ms/step - loss: 0.0343 - accuracy: 0.9904 - val_loss: 0.0728 - val_accuracy: 0.9782
# Epoch 5/10
# 600/600 [==============================] - 7s 11ms/step - loss: 0.0245 - accuracy: 0.9933 - val_loss: 0.0676 - val_accuracy: 0.9788
# Epoch 6/10
# 600/600 [==============================] - 6s 11ms/step - loss: 0.0170 - accuracy: 0.9952 - val_loss: 0.0676 - val_accuracy: 0.9785
# Epoch 7/10
# 600/600 [==============================] - 6s 11ms/step - loss: 0.0124 - accuracy: 0.9966 - val_loss: 0.0626 - val_accuracy: 0.9811
# Epoch 8/10
# 600/600 [==============================] - 7s 11ms/step - loss: 0.0094 - accuracy: 0.9973 - val_loss: 0.0682 - val_accuracy: 0.9818
# Epoch 9/10
# 600/600 [==============================] - 7s 11ms/step - loss: 0.0114 - accuracy: 0.9964 - val_loss: 0.0694 - val_accuracy: 0.9812
# Epoch 10/10
# 600/600 [==============================] - 7s 12ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0692 - val_accuracy: 0.9823
# Fit time : 66.87049603462219

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plot_target =['loss', 'val_loss', 'accuracy', 'val_accuracy']

plt.figure(figsize=(12,8))

for each in plot_target:
    plt.plot(hist.history[each], label=each)
    
plt.legend()
plt.grid()
plt.show()

# %%
score = model.evaluate(X_test, y_test)
print('Test loss :', score[0])
print('Test accuracy :', score[1])
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.0692 - accuracy: 0.9823
# Test loss : 0.06915603578090668
# Test accuracy : 0.9822999835014343

# %%
import numpy as np

predicted_result = model.predict(X_test)
predicted_labels = np.argmax(predicted_result, axis=1)
predicted_labels[:10]
# Out:
# array([7, 2, 1, 0, 4, 1, 4, 9, 5, 9], dtype=int64)

# %%
y_test[:10]
# Out:
# array([7, 2, 1, 0, 4, 1, 4, 9, 5, 9], dtype=uint8)

# %%
wrong_result = []

for n in range(0, len(y_test)):
    if predicted_labels[n] != y_test[n]:
        wrong_result.append(n)
        
len(wrong_result)
# Out:
# 177

# %%
import random

samples = random.choices(population=wrong_result, k=16)
samples
# Out:
# [1800,
#  5676,
#  9768,
#  6560,
#  3597,
#  5331,
#  3520,
#  2118,
#  3597,
#  4000,
#  2730,
#  2953,
#  1182,
#  5734,
#  2648,
#  2597]

# %%
plt.figure(figsize=(14,12))

for idx, n in enumerate(samples):
    plt.subplot(4, 4, idx+1)
    plt.imshow(X_test[n].reshape(28,28), cmap='Greys', interpolation='nearest')
    plt.title('Labe : ' + str(y_test[n]) + ' Predict : ' + str(predicted_labels[n]))
    plt.axis('off')

plt.show()

# %% [markdown]
# MNIST fashion

# %%
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train, X_test = X_train / 255.0, X_test /255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline

samples = random.choices(population=range(0,len(y_train)), k=16)

# %%
plt.figure(figsize=(14, 12))

for idx, n in enumerate(samples):
    plt.subplot(4, 4, idx+1)
    plt.imshow(X_train[n].reshape(28,28), cmap='Greys', interpolation='nearest')
    plt.title('Label : ' + str(y_train[n]) )
    plt.axis('off')
    
plt.show()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1000)              785000
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                10010
# =================================================================
# Total params: 795,010
# Trainable params: 795,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time

start_time = time.time()
hist = model.fit(X_train, y_train, validation_data=(X_test, y_test),
                epochs=10, batch_size=100, verbose=1)
print('Fit time :', time.time() - start_time)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 7s 11ms/step - loss: 0.6240 - accuracy: 0.7812 - val_loss: 0.4048 - val_accuracy: 0.8578
# Epoch 2/10
# 600/600 [==============================] - 6s 11ms/step - loss: 0.3789 - accuracy: 0.8634 - val_loss: 0.4166 - val_accuracy: 0.8478
# Epoch 3/10
# 600/600 [==============================] - 6s 11ms/step - loss: 0.3240 - accuracy: 0.8813 - val_loss: 0.3990 - val_accuracy: 0.8510
# Epoch 4/10
# 600/600 [==============================] - 6s 10ms/step - loss: 0.2988 - accuracy: 0.8890 - val_loss: 0.3431 - val_accuracy: 0.8768
# Epoch 5/10
# 600/600 [==============================] - 6s 10ms/step - loss: 0.2753 - accuracy: 0.8980 - val_loss: 0.3289 - val_accuracy: 0.8807
# Epoch 6/10
# 600/600 [==============================] - 6s 10ms/step - loss: 0.2619 - accuracy: 0.9029 - val_loss: 0.3272 - val_accuracy: 0.8828
# Epoch 7/10
# 600/600 [==============================] - 6s 11ms/step - loss: 0.2533 - accuracy: 0.9041 - val_loss: 0.3464 - val_accuracy: 0.8761
# Epoch 8/10
# 600/600 [==============================] - 6s 10ms/step - loss: 0.2383 - accuracy: 0.9111 - val_loss: 0.3238 - val_accuracy: 0.8844
# Epoch 9/10
# 600/600 [==============================] - 6s 10ms/step - loss: 0.2241 - accuracy: 0.9160 - val_loss: 0.3457 - val_accuracy: 0.8762
# Epoch 10/10
# 600/600 [==============================] - 6s 10ms/step - loss: 0.2199 - accuracy: 0.9175 - val_loss: 0.3230 - val_accuracy: 0.8845
# Fit time : 63.406534910202026

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plot_target = ['loss', 'val_loss', 'accuracy', 'val_accuracy']

plt.figure(figsize=(12,8))

for each in plot_target:
    plt.plot(hist.history[each], label=each)
    
plt.legend()
plt.grid()
plt.show()

# %%
score = model.evaluate(X_test, y_test)
print('Test loss :', score[0])
print('Test accuracy :', score[1])
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.3230 - accuracy: 0.8845
# Test loss : 0.32303255796432495
# Test accuracy : 0.8845000267028809

# %%
import numpy as np

predicted_result = model.predict(X_test)
predicted_labels = np.argmax(predicted_result, axis=1)
predicted_labels[:10]
# Out:
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7], dtype=int64)

# %%
y_test[:10]
# Out:
# array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7], dtype=uint8)

# %%
wrong_result = []

for n in range(0, len(y_test)):
    if predicted_labels[n] != y_test[n]:
        wrong_result.append(n)
        
len(wrong_result)
# Out:
# 1155

# %%
import random

samples = random.choices(population=wrong_result, k=16)
samples
# Out:
# [404,
#  5065,
#  5601,
#  9062,
#  6994,
#  5661,
#  9644,
#  3188,
#  6437,
#  5721,
#  7876,
#  7323,
#  5440,
#  9033,
#  2798,
#  4922]

# %%
plt.figure(figsize=(14,12))

for idx, n in enumerate(samples):
    plt.subplot(4, 4, idx+1)
    plt.imshow(X_test[n].reshape(28,28), cmap='Greys', interpolation='nearest')
    plt.title('Label : ' + str(y_test[n]) + ' Predict : ' + str(predicted_labels[n]))
    plt.axis('off')
    
plt.show()
